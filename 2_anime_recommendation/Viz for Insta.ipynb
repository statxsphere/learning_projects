# %%
import pandas as pd
import re
import numpy as np
import scipy as sp
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
import operator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
anime = pd.read_csv('data1/finalanime1.csv')

# %%
anime.head()
# Out:
#    anime_id                 name type    source  episodes           status  \
# 0     11013        Inu x Boku SS   TV     Manga        12  Finished Airing
# 1      2104     Seto no Hanayome   TV     Manga        26  Finished Airing
# 2      5262   Shugo Chara!! Doki   TV     Manga        51  Finished Airing
# 3       721        Princess Tutu   TV  Original        38  Finished Airing
# 4     12365  Bakuman. 3rd Season   TV     Manga        25  Finished Airing
#
#    rating  members  favorites   genre  duration_min  aired_from_year
# 0    7.63   283882       2809  Comedy          24.0           2012.0
# 1    7.89   204003       2579  Comedy          24.0           2007.0
# 2    7.55    70127        802  Comedy          24.0           2008.0
# 3    8.21    93312       3344  Comedy          16.0           2002.0
# 4    8.67   182765       2082  Comedy          24.0           2012.0

# %%
sns.set_theme(style='dark')
sns.
sns.relplot(y='episodes',x='aired_from_year',data=anime,size='members', sizes=(100,1000), height=8,aspect=1.6)
